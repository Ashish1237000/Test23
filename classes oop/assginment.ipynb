# %% [markdown]
# ![Screenshot 2025-02-20 153716.png](<attachment:Screenshot 2025-02-20 153716.png>)

# %% [markdown]
# ![Screenshot 2025-02-20 154536.png](<attachment:Screenshot 2025-02-20 154536.png>)

# %% [markdown]
# ![Screenshot 2025-02-20 154604.png](<attachment:Screenshot 2025-02-20 154604.png>)

# %%
from dataclasses import dataclass

# %%
@dataclass
class Triangle:
    a: int | float
    b: int | float
    c: int | float

    def is_triangle(self):
        if ((self.a + self.b > self.c) and 
            (self.b + self.c > self.a) and 
            (self.c + self.a > self.c)):
            return True
        else:
            return False
        
    def perimeter(self):
        if self.is_triangle():
            p = self.a + self.b + self.c
            return p
        else:
            raise ValueError(f"Given sides {self.a}, {self.b}, {self.c} do not form a triangle")
    
    def area(self):
        s = self.perimeter() / 2
        a = (s * (s - self.a) * (s - self.b) * (s - self.c))**(1 / 2)
        return a

# %%
t1 = Triangle(a = 3, b = 4, c = 6)
t1
# Out:
# Triangle(a=3, b=4, c=6)

# %%
print(type(t1))
# Out:
# <class '__main__.Triangle'>

# %%
t1.a
# Out:
# 3

# %%
t1.b
# Out:
# 4

# %%
t1.c
# Out:
# 6

# %%
t1.is_triangle()
# Out:
# True

# %%
p1 = t1.perimeter()
p1
# Out:
# 13

# %%
a1 = t1.area()
a1
# Out:
# 5.332682251925386

# %% [markdown]
# Another traingle that does form a triangle

# %%
t2 = Triangle(1, 2, 4)

# %%
t2.is_triangle()
# Out:
# False

# %%
t2.perimeter()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 t2.perimeter()
#
# Cell In[3], line 20, in Triangle.perimeter(self)
#      18     return p
#      19 else:
# ---> 20     raise ValueError(f"Given sides {self.a}, {self.b}, {self.c} do not form a triangle")
#
# ValueError: Given sides 1, 2, 4 do not form a triangle

# %%
t2.area()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 t2.area()
#
# Cell In[3], line 23, in Triangle.area(self)
#      22 def area(self):
# ---> 23     s = self.perimeter() / 2
#      24     a = (s * (s - self.a) * (s - self.b) * (s - self.c))**(1 / 2)
#      25     return a
#
# Cell In[3], line 20, in Triangle.perimeter(self)
#      18     return p
#      19 else:
# ---> 20     raise ValueError(f"Given sides {self.a}, {self.b}, {self.c} do not form a triangle")
#
# ValueError: Given sides 1, 2, 4 do not form a triangle

# %% [markdown]
# Calulating perimeter and area for multiple traingles

# %%
t1 = Triangle(3, 4, 5)
t2 = Triangle(12, 13, 14)
t3 = Triangle(4, 5, 7)
t4 = Triangle(1, 2, 2)

# %%
t = [t1, t2, t3, t4]
t
# Out:
# [Triangle(a=3, b=4, c=5),
#  Triangle(a=12, b=13, c=14),
#  Triangle(a=4, b=5, c=7),
#  Triangle(a=1, b=2, c=2)]

# %%
for i in t:
    print(i)
    print(f"Is triangle : {i.is_triangle()}")
    print(f"Perimeter of triangle : {i.perimeter():.2f}")
    print(f"Area of triangle : {i.area():.2f}")
    print("\n========================================================\n")
